# %%
#telecome customer behaviour
print("the notebook is running well")
# Out:
# the notebook is running well

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("telec info.csv")

# %%
data.head(100)
# Out:
#     customerID  gender SeniorCitizen(old people) ALREADY LEFT LAST MONTH  \
# 0   0003-MKNFE    Male                        NO                      No
# 1   0004-TLHLJ    Male                        NO                     Yes
# 2   0013-MHZWF  Female                        NO                      No
# 3   0015-UOCOJ  Female                       YES                      No
# 4   0017-DINOC    Male                        NO                      No
# ..         ...     ...                       ...                     ...
# 95  0310-VQXAM    Male                        NO                      No
# 96  0311-QYWSS  Female                        NO                      No
# 97  0311-UNPFF  Female                        NO                     Yes
# 98  0314-TKOSI  Female                        NO                      No
# 99  0315-LVCRK    Male                        NO                      No
#
#    Partner Dependents PhoneService     MultipleLines InternetService  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3641 entries, 0 to 3640
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customerID                      3641 non-null   object
#  1   gender                          3641 non-null   object
#  2   SeniorCitizen(old people)       3641 non-null   object
#  3   ALREADY LEFT LAST MONTH         3641 non-null   object
#  4   Partner                         3641 non-null   object
#  5   Dependents                      3641 non-null   object
#  6   PhoneService                    3641 non-null   object
#  7   MultipleLines                   3641 non-null   object
#  8   InternetService                 3641 non-null   object
#  9   OnlineSecurity                  3641 non-null   object
#  10  OnlineBackup                    3641 non-null   object
#  11  DeviceProtection                3641 non-null   object
# ...

# %%
duplicated =data.duplicated().any()
duplicated
# Out:
# False

# %%
check_nan = data.isnull().any()
check_nan
# Out:
# customerID                        False
# gender                            False
# SeniorCitizen(old people)         False
# ALREADY LEFT LAST MONTH           False
# Partner                           False
# Dependents                        False
# PhoneService                      False
# MultipleLines                     False
# InternetService                   False
# OnlineSecurity                    False
# OnlineBackup                      False
# DeviceProtection                  False
# TechSupport                       False
# StreamingTV                       False
# StreamingMovies                   False
# Contract                          False
# PaperlessBilling                  False
# PaymentMethod                     False
# MonthlyCharges                    False
# TotalCharges                       True
# contracting  period  per month    False
# dtype: bool

# %%
 data.dtypes
# Out:
# customerID                         object
# gender                             object
# SeniorCitizen(old people)          object
# ALREADY LEFT LAST MONTH            object
# Partner                            object
# Dependents                         object
# PhoneService                       object
# MultipleLines                      object
# InternetService                    object
# OnlineSecurity                     object
# OnlineBackup                       object
# DeviceProtection                   object
# TechSupport                        object
# StreamingTV                        object
# StreamingMovies                    object
# Contract                           object
# PaperlessBilling                   object
# PaymentMethod                      object
# MonthlyCharges                    float64
# TotalCharges                      float64
# contracting  period  per month      int64
# dtype: object

# %%
data["TotalCharges"].mean()
data.fillna(1584.9604286891977, inplace = True)
data["TotalCharges"].mean()

check_nan = data.isnull().any()
check_nan
# Out:
# customerID                        False
# gender                            False
# SeniorCitizen(old people)         False
# ALREADY LEFT LAST MONTH           False
# Partner                           False
# Dependents                        False
# PhoneService                      False
# MultipleLines                     False
# InternetService                   False
# OnlineSecurity                    False
# OnlineBackup                      False
# DeviceProtection                  False
# TechSupport                       False
# StreamingTV                       False
# StreamingMovies                   False
# Contract                          False
# PaperlessBilling                  False
# PaymentMethod                     False
# MonthlyCharges                    False
# TotalCharges                      False
# contracting  period  per month    False
# dtype: bool

# %%
#total no.of customers 
data['customerID'].value_counts().to_frame()
# Out:
#             customerID
# 0003-MKNFE           1
# 6734-FQAJX           1
# 6683-VLCTZ           1
# 6686-YPGHK           1
# 6689-KXGBO           1
# ...                ...
# 3489-VSFRD           1
# 3494-JCHRQ           1
# 3500-RMZLT           1
# 3506-OVLKD           1
# 9992-UJOEL           1
#
# [3641 rows x 1 columns]

# %%
#studying the customer behaviour regarding to their personallites (gender ,age , still a customer or left...,etc )

# %%
#no.males & Females
data['gender'].value_counts().to_frame()
# Out:
#         gender
# Male      1841
# Female    1800

# %%
 
#total no.of old people
data['SeniorCitizen(old people)'].value_counts().to_frame()
# Out:
#      SeniorCitizen(old people)
# NO                        3072
# YES                        569

# %%
#no .of customers who left last month
data['ALREADY LEFT LAST MONTH'].value_counts().to_frame()
# Out:
#      ALREADY LEFT LAST MONTH
# No                      2441
# Yes                     1200

# %%
#no .of customers who have a partner
data['Partner'].value_counts().to_frame()
# Out:
#     Partner
# No     3641

# %%
#no .of customers who have a depentants
data['Dependents'].value_counts().to_frame()
# Out:
#      Dependents
# No         3280
# Yes         361

# %%
#no .of customers who get aphone service
data['PhoneService'].value_counts().to_frame()
# Out:
#      PhoneService
# Yes          3270
# No            371

# %%
#no .of customers who get MultipleLines
data['MultipleLines'].value_counts().to_frame()
# Out:
#                   MultipleLines
# No                         1981
# Yes                        1289
# No phone service            371

# %%
#no .of customers who get InternetService
data['InternetService'].value_counts().to_frame()
# Out:
#              InternetService
# Fiber optic             1600
# DSL                     1253
# No                       788

# %%
#no .of customers who get OnlineSecurity
data['OnlineSecurity'].value_counts().to_frame()
# Out:
#                      OnlineSecurity
# No                             2037
# Yes                             816
# No internet service             788

# %%
#no .of customers who getDeviceProtection
data['DeviceProtection'].value_counts().to_frame()
# Out:
#                      DeviceProtection
# No                               1858
# Yes                               995
# No internet service               788

# %%
#no .of customers who get TechSupport
data['TechSupport'].value_counts().to_frame()
# Out:
#                      TechSupport
# No                          1988
# Yes                          865
# No internet service          788

# %%
#no .of customers who get StreamingTV
data['StreamingTV'].value_counts().to_frame()
# Out:
#                      StreamingTV
# No                          1667
# Yes                         1186
# No internet service          788

# %%
#no .of customers who get StreamingMovies 
data['StreamingMovies'].value_counts().to_frame()
# Out:
#                      StreamingMovies
# No                              1642
# Yes                             1211
# No internet service              788

# %%
round(data["TotalCharges"].agg(('max','min','sum','mean'),axis=0).to_frame())
# Out:
#       TotalCharges
# max         8547.0
# min           19.0
# sum      5770841.0
# mean        1585.0

# %%
round(data["MonthlyCharges"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       MonthlyCharges
# max            119.0
# min             18.0
# sum         225542.0
# mean            62.0

# %%
data["PaymentMethod"].value_counts().to_frame()
# Out:
#                            PaymentMethod
# Electronic check                    1362
# Mailed check                         974
# Credit card (automatic)              668
# Bank transfer (automatic)            637

# %%
data["Contract"].value_counts().to_frame()
# Out:
#                 Contract
# Month-to-month      2495
# One year             643
# Two year             503

# %%
round(data["contracting  period  per month"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       contracting  period  per month
# max                             72.0
# min                              0.0
# sum                          85046.0
# mean                            23.0

# %%
#studying the male customers behaviour
dx=data[data['gender']== 'Male']
   
dx
# Out:
#       customerID gender SeniorCitizen(old people) ALREADY LEFT LAST MONTH  \
# 0     0003-MKNFE   Male                        NO                      No
# 1     0004-TLHLJ   Male                        NO                     Yes
# 4     0017-DINOC   Male                        NO                      No
# 8     0022-TCJCI   Male                       YES                     Yes
# 9     0023-HGHWL   Male                       YES                     Yes
# ...          ...    ...                       ...                     ...
# 3629  9965-YOKZB   Male                       YES                     Yes
# 3631  9968-FFVVH   Male                        NO                      No
# 3634  9974-JFBHQ   Male                        NO                      No
# 3635  9975-SKRNR   Male                        NO                      No
# 3640  9992-UJOEL   Male                        NO                      No
#
#      Partner Dependents PhoneService     MultipleLines InternetService  \
# ...

# %%
#no of males &senior citizen
dx["SeniorCitizen(old people)"].value_counts().to_frame()
# Out:
#      SeniorCitizen(old people)
# NO                        1592
# YES                        249

# %%
#no of males & ALREADY LEFT LAST MONTH
dx["ALREADY LEFT LAST MONTH"].value_counts().to_frame()
# Out:
#      ALREADY LEFT LAST MONTH
# No                      1261
# Yes                      580

# %%
#no of males & have A dependents
dx["Dependents"].value_counts().to_frame()
# Out:
#      Dependents
# No         1625
# Yes         216

# %%
#no of males & have A partener
dx["Partner"].value_counts().to_frame()
# Out:
#     Partner
# No     1841

# %%
#no of males for each service
dx["PhoneService"].value_counts().to_frame()
# Out:
#      PhoneService
# Yes          1652
# No            189

# %%
dx["MultipleLines"].value_counts().to_frame()
# Out:
#                   MultipleLines
# No                         1024
# Yes                         628
# No phone service            189

# %%
dx["InternetService"].value_counts().to_frame()
# Out:
#              InternetService
# Fiber optic              763
# DSL                      635
# No                       443

# %%
dx["OnlineSecurity"].value_counts().to_frame()
# Out:
#                      OnlineSecurity
# No                             1018
# No internet service             443
# Yes                             380

# %%
dx["DeviceProtection"].value_counts().to_frame()
# Out:
#                      DeviceProtection
# No                                930
# Yes                               468
# No internet service               443

# %%
dx["StreamingTV"].value_counts().to_frame()
# Out:
#                      StreamingTV
# No                           822
# Yes                          576
# No internet service          443

# %%
dx["StreamingMovies"].value_counts().to_frame()
# Out:
#                      StreamingMovies
# No                               816
# Yes                              582
# No internet service              443

# %%
dx["Contract"].value_counts().to_frame()
# Out:
#                 Contract
# Month-to-month      1260
# One year             321
# Two year             260

# %%
dx["PaperlessBilling"].value_counts().to_frame()
# Out:
# Yes    1075
# No      766
# Name: PaperlessBilling, dtype: int64

# %%
dx["PaymentMethod"].value_counts().to_frame()
# Out:
#                            PaymentMethod
# Electronic check                     663
# Mailed check                         524
# Credit card (automatic)              330
# Bank transfer (automatic)            324

# %%
round(dx["TotalCharges"].agg(('max','min','sum','mean'),axis=0).to_frame())
# Out:
#       TotalCharges
# max         8547.0
# min           19.0
# sum      2838088.0
# mean        1543.0

# %%
round(dx["MonthlyCharges"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       MonthlyCharges
# max            118.0
# min             18.0
# sum         110568.0
# mean            60.0

# %%
round(dx["contracting  period  per month"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       contracting  period  per month
# max                             72.0
# min                              0.0
# sum                          43237.0
# mean                            23.0

# %%
#studying the male customers behaviour
dz=data[data['gender']== 'Female']
   
dz
# Out:
#       customerID  gender SeniorCitizen(old people) ALREADY LEFT LAST MONTH  \
# 2     0013-MHZWF  Female                        NO                      No
# 3     0015-UOCOJ  Female                       YES                      No
# 5     0019-EFAEP  Female                        NO                      No
# 6     0019-GFNTW  Female                        NO                      No
# 7     0021-IKXGC  Female                       YES                      No
# ...          ...     ...                       ...                     ...
# 3633  9972-NKTFD  Female                        NO                      No
# 3636  9979-RGMZT  Female                        NO                      No
# 3637  9985-MWVIX  Female                        NO                     Yes
# 3638  9986-BONCE  Female                        NO                     Yes
# 3639  9987-LUTYD  Female                        NO                      No
#
# ...

# %%
#no of Females &senior citizen
dz["SeniorCitizen(old people)"].value_counts().to_frame()
# Out:
#      SeniorCitizen(old people)
# NO                        1480
# YES                        320

# %%
#no of Females & ALREADY LEFT LAST MONTH
dz["ALREADY LEFT LAST MONTH"].value_counts().to_frame()
# Out:
#      ALREADY LEFT LAST MONTH
# No                      1180
# Yes                      620

# %%
#no of Females & have A dependents
dz["Dependents"].value_counts().to_frame()
# Out:
#      Dependents
# No         1655
# Yes         145

# %%
#no of Females & have A partener
dz["Partner"].value_counts().to_frame()
# Out:
#     Partner
# No     1800

# %%
#no of Females for each service
dz["PhoneService"].value_counts().to_frame()
# Out:
#      PhoneService
# Yes          1618
# No            182

# %%
dz["MultipleLines"].value_counts().to_frame()
# Out:
#                   MultipleLines
# No                          957
# Yes                         661
# No phone service            182

# %%
dz["InternetService"].value_counts().to_frame()
# Out:
#              InternetService
# Fiber optic              837
# DSL                      618
# No                       345

# %%
dz["OnlineSecurity"].value_counts().to_frame()
# Out:
#                      OnlineSecurity
# No                             1019
# Yes                             436
# No internet service             345

# %%
dz["DeviceProtection"].value_counts().to_frame()
# Out:
#                      DeviceProtection
# No                                928
# Yes                               527
# No internet service               345

# %%
dz["StreamingTV"].value_counts().to_frame()
# Out:
#                      StreamingTV
# No                           845
# Yes                          610
# No internet service          345

# %%
dz["StreamingMovies"].value_counts().to_frame()
# Out:
#                      StreamingMovies
# No                               826
# Yes                              629
# No internet service              345

# %%
round(dz["TotalCharges"].agg(('max','min','sum','mean'),axis=0).to_frame())
# Out:
#       TotalCharges
# max         8497.0
# min           19.0
# sum      2929583.0
# mean        1628.0

# %%
round(dz["MonthlyCharges"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       MonthlyCharges
# max            119.0
# min             19.0
# sum         114973.0
# mean            64.0

# %%
round(dz["contracting  period  per month"].agg(('max','min','sum','mean'),axis=0  ).to_frame())
# Out:
#       contracting  period  per month
# max                             72.0
# min                              1.0
# sum                          41809.0
# mean                            23.0

# %%
dz["Contract"].value_counts().to_frame()
# Out:
#                 Contract
# Month-to-month      1235
# One year             322
# Two year             243

# %%
#studying the customer behaviour regarding to their desired services

# %%
data
# Out:
#       customerID  gender SeniorCitizen(old people) ALREADY LEFT LAST MONTH  \
# 0     0003-MKNFE    Male                        NO                      No
# 1     0004-TLHLJ    Male                        NO                     Yes
# 2     0013-MHZWF  Female                        NO                      No
# 3     0015-UOCOJ  Female                       YES                      No
# 4     0017-DINOC    Male                        NO                      No
# ...          ...     ...                       ...                     ...
# 3636  9979-RGMZT  Female                        NO                      No
# 3637  9985-MWVIX  Female                        NO                     Yes
# 3638  9986-BONCE  Female                        NO                     Yes
# 3639  9987-LUTYD  Female                        NO                      No
# 3640  9992-UJOEL    Male                        NO                      No
#
# ...

# %%
dy= data[['customerID','PhoneService','MultipleLines','InternetService','OnlineSecurity','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']]
dy
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 0     0003-MKNFE          Yes               Yes             DSL
# 1     0004-TLHLJ          Yes                No     Fiber optic
# 2     0013-MHZWF          Yes                No             DSL
# 3     0015-UOCOJ          Yes                No             DSL
# 4     0017-DINOC           No  No phone service             DSL
# ...          ...          ...               ...             ...
# 3636  9979-RGMZT          Yes                No     Fiber optic
# 3637  9985-MWVIX          Yes                No     Fiber optic
# 3638  9986-BONCE          Yes                No              No
# 3639  9987-LUTYD          Yes                No             DSL
# 3640  9992-UJOEL          Yes                No             DSL
#
#            OnlineSecurity     DeviceProtection          TechSupport  \
# 0                      No                   No                   No
# ...

# %%
dy[dy['PhoneService']== 'Yes']
dr=dy[dy['MultipleLines']== 'Yes']

dr
# Out:
#       customerID PhoneService MultipleLines InternetService  \
# 0     0003-MKNFE          Yes           Yes             DSL
# 5     0019-EFAEP          Yes           Yes     Fiber optic
# 7     0021-IKXGC          Yes           Yes     Fiber optic
# 13    0057-QBUQH          Yes           Yes              No
# 21    0083-PIVIK          Yes           Yes             DSL
# ...          ...          ...           ...             ...
# 3623  9944-AEXBM          Yes           Yes     Fiber optic
# 3626  9953-ZMKSM          Yes           Yes              No
# 3627  9959-WOFKT          Yes           Yes     Fiber optic
# 3629  9965-YOKZB          Yes           Yes     Fiber optic
# 3631  9968-FFVVH          Yes           Yes             DSL
#
#            OnlineSecurity     DeviceProtection          TechSupport  \
# 0                      No                   No                   No
# 5                     Yes                  Yes                   No
# ...

# %%
ds=dr[dr['InternetService']== 'DSL']
ds['customerID'].value_counts().to_frame()
# Out:
#             customerID
# 0003-MKNFE           1
# 6741-QRLUP           1
# 6923-EFPNL           1
# 6907-FLBER           1
# 6901-GOGZG           1
# ...                ...
# 3351-NGXYI           1
# 3401-URHDA           1
# 3413-CSSTH           1
# 3426-NIYYL           1
# 9968-FFVVH           1
#
# [272 rows x 1 columns]

# %%
dr[dr['InternetService']== 'Fiber optic']
dr['customerID'].value_counts().to_frame()
# Out:
#             customerID
# 0003-MKNFE           1
# 7000-WCEVQ           1
# 6838-YAUVY           1
# 6825-UYPFK           1
# 6821-BUXUX           1
# ...                ...
# 3370-HXOPH           1
# 3352-ALMCK           1
# 3351-NGXYI           1
# 3349-ANQNH           1
# 9968-FFVVH           1
#
# [1289 rows x 1 columns]

# %%
#total people who have multiplylines& have internet srvices 
1289+272
# Out:
# 1561

# %%
dy= data[['customerID','OnlineSecurity','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']]
dy
# Out:
#       customerID       OnlineSecurity     DeviceProtection  \
# 0     0003-MKNFE                   No                   No
# 1     0004-TLHLJ                   No                  Yes
# 2     0013-MHZWF                   No                   No
# 3     0015-UOCOJ                  Yes                   No
# 4     0017-DINOC                  Yes                   No
# ...          ...                  ...                  ...
# 3636  9979-RGMZT                   No                   No
# 3637  9985-MWVIX                   No                   No
# 3638  9986-BONCE  No internet service  No internet service
# 3639  9987-LUTYD                  Yes                   No
# 3640  9992-UJOEL                   No                   No
#
#               TechSupport          StreamingTV      StreamingMovies
# 0                      No                   No                  Yes
# 1                      No                   No                   No
# ...

# %%
dyy=dy[dy['OnlineSecurity']== 'Yes']
dyy
# Out:
#       customerID OnlineSecurity DeviceProtection TechSupport StreamingTV  \
# 3     0015-UOCOJ            Yes               No          No          No
# 4     0017-DINOC            Yes               No         Yes         Yes
# 5     0019-EFAEP            Yes              Yes          No         Yes
# 6     0019-GFNTW            Yes              Yes         Yes          No
# 8     0022-TCJCI            Yes              Yes          No          No
# ...          ...            ...              ...         ...         ...
# 3616  9928-BZVLZ            Yes              Yes         Yes          No
# 3620  9938-EKRGF            Yes              Yes         Yes         Yes
# 3627  9959-WOFKT            Yes              Yes          No         Yes
# 3631  9968-FFVVH            Yes              Yes         Yes          No
# 3639  9987-LUTYD            Yes               No         Yes          No
#
#      StreamingMovies
# 3                 No
# 4                 No
# 5                 No
# ...

# %%
dxx=dyy[dyy["DeviceProtection"]== "Yes"]
dxx
# Out:
#       customerID OnlineSecurity DeviceProtection TechSupport StreamingTV  \
# 5     0019-EFAEP            Yes              Yes          No         Yes
# 6     0019-GFNTW            Yes              Yes         Yes          No
# 8     0022-TCJCI            Yes              Yes          No          No
# 16    0076-LVEPS            Yes              Yes         Yes          No
# 21    0083-PIVIK            Yes              Yes         Yes         Yes
# ...          ...            ...              ...         ...         ...
# 3615  9924-JPRMC            Yes              Yes         Yes         Yes
# 3616  9928-BZVLZ            Yes              Yes         Yes          No
# 3620  9938-EKRGF            Yes              Yes         Yes         Yes
# 3627  9959-WOFKT            Yes              Yes          No         Yes
# 3631  9968-FFVVH            Yes              Yes         Yes          No
#
#      StreamingMovies
# 5                 No
# 6                 No
# 8                Yes
# ...

# %%
#no of customers who have online security & device protection 
376
# Out:
# 376

# %%
dzz=dxx[dxx["TechSupport"]== "Yes"]
dzz
# Out:
#       customerID OnlineSecurity DeviceProtection TechSupport StreamingTV  \
# 6     0019-GFNTW            Yes              Yes         Yes          No
# 16    0076-LVEPS            Yes              Yes         Yes          No
# 21    0083-PIVIK            Yes              Yes         Yes         Yes
# 46    0164-APGRB            Yes              Yes         Yes         Yes
# 49    0186-CAERR            Yes              Yes         Yes         Yes
# ...          ...            ...              ...         ...         ...
# 3610  9909-DFRJA            Yes              Yes         Yes          No
# 3615  9924-JPRMC            Yes              Yes         Yes         Yes
# 3616  9928-BZVLZ            Yes              Yes         Yes          No
# 3620  9938-EKRGF            Yes              Yes         Yes         Yes
# 3631  9968-FFVVH            Yes              Yes         Yes          No
#
#      StreamingMovies
# 6                 No
# 16                No
# 21                No
# ...

# %%
#no of customers who have online security & device protection and have the techsupport
235
# Out:
# 235
